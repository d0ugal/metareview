# %%
# %pylab inline

import pandas as pd
import numpy as np

pylab.rcParams['figure.figsize'] = 20, 5
pd.set_option('display.max_columns', 40)
pd.set_option('display.max_rows', 200)

from review_analysis.sources.gerrit import Gerrit
from review_analysis import reports
print "Finished setup"
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Finished setup

# %%
print "Loading reviews..."
df = Gerrit(cache_only=True).as_dataframe()
print "Loaded {0} reviews".format(len(df))
# Out:
# Loading reviews...
# Loaded 125836 reviews

# %%
reports.sloc.size_vs_reviews(df).plot()

# %%
reports.sloc.size_vs_reviews(df, 'lines_total').plot()

# %%
reports.sloc.size_vs_reviews(df, 'lines_inserted').plot()

# %%
reports.sloc.size_vs_reviews(df, 'lines_deleted').plot()
